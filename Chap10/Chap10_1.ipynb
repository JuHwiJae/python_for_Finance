# %% [markdown]
# # 10.1 난수 생성

# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# [0,1) 사이의 난수 생성
npr.rand(10)
# Out:
# array([0.36069668, 0.25531389, 0.97637029, 0.95827175, 0.56539916,
#        0.00558971, 0.468189  , 0.56735885, 0.78981798, 0.2046414 ])

# %%
npr.rand(5,5)
# Out:
# array([[0.54950852, 0.01159433, 0.09143454, 0.9309619 , 0.29874869],
#        [0.32306975, 0.73135729, 0.96155235, 0.98364279, 0.26947019],
#        [0.00844436, 0.13640935, 0.00671098, 0.00322128, 0.17101544],
#        [0.71705782, 0.95626099, 0.30510164, 0.8233197 , 0.12704103],
#        [0.40719365, 0.99352922, 0.31960026, 0.70401508, 0.09533269]])

# %%
# 필요한 구간의 숫자로 변경
a = 5.
b = 10.
npr.rand(10) * (b - a) + a # -> [5,10) 구간으로 생성
# Out:
# array([6.66510386, 7.06700339, 8.00860053, 7.54873466, 7.78176481,
#        6.36271003, 5.88810897, 7.42058766, 7.01834179, 5.92120796])

# %%
npr.rand(5,5) * (b - a) + a
# Out:
# array([[5.0832044 , 9.15105991, 5.32684447, 6.36625063, 8.83535436],
#        [7.73914413, 8.75925719, 9.26783244, 9.80421789, 7.53529579],
#        [5.20253393, 7.31526982, 9.88326241, 6.43508879, 6.39496182],
#        [7.16668454, 6.11827564, 7.06798901, 6.19211289, 8.64862193],
#        [6.44266411, 8.89768414, 7.35713632, 7.14372817, 7.30314722]])

# %% [markdown]
# 난수 생성 함수 p.323
#  - rand
#  - randn : 표준정규분포의 샘플 생성
#  - randint 등등

# %%
sample_size = 500
rn1 = npr.rand(sample_size, 3)
rn2 = npr.randint(0,10,sample_size)
rn3 = npr.sample(size = sample_size) # [0, 1) 구간의 float형 난수
a = [0, 25, 50, 75, 100]
rn4 = npr.choice(a, size = sample_size) # 주어진 1차원 배열에서 무작위 샘플 생성

# rand, sample : 연속
# randint, choice : 이산

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2,
                                            figsize = (7,7))
ax1.hist(rn1, bins = 25, stacked = True)
ax1.set_title('rand')
ax1.set_ylabel('frequency')
ax1.grid(True)
ax2.hist(rn2, bins = 25)
ax2.set_title('randint')
ax2.grid(True)
ax3.hist(rn3, bins = 25)
ax3.set_title('sample')
ax3.set_ylabel('frequency')
ax3.grid(True)
ax4.hist(rn4, bins = 25)
ax4.set_title('choice')
ax4.grid(True)

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/legacy.html

# %% [markdown]
# 특정 확률 분포 따르는 난수 함수 p.325
#  - beta
#  - binomial 등등

# %% [markdown]
# 표준정규분포 이견 but, 정규분포 or 로그 정규분포 많이 사용

# %%
# 평균 0, 표준편차 1 인 표준정규분포
# 평균 100, 표준편차 20 인 정규분포
# 자유도 0.5 인 카이제곱 분포
# 람다 계수 1 인 포아송분포

# %%
sample_size = 500
rn1 = npr.standard_normal(sample_size)
rn2 = npr.normal(100, 20, sample_size)
rn3 = npr.chisquare(df = 0.5, size = sample_size)
rn4 = npr.poisson(lam = 1.0, size = sample_size) # 외부 쇼크 or 갑작스런 상품 가격 변화 등
                                                 # 드물게 발생하는 사건의 발생 분포 시뮬레이션

# 표준정규분포, 정규분포, 카이제곱분포 : 연속
# 포아송분포 : 이산

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2,
                                            figsize = (7,7))
ax1.hist(rn1, bins = 25)
ax1.set_title('standard normal')
ax1.set_ylabel('frequency')
ax1.grid(True)
ax2.hist(rn2, bins = 25)
ax2.set_title('normal(100,20)')
ax2.grid(True)
ax3.hist(rn3, bins = 25)
ax3.set_title('chi square')
ax3.set_ylabel('frequency')
ax3.grid(True)
ax4.hist(rn4, bins = 25)
ax4.set_title('poisson')
ax4.grid(True)
