# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1차원 자료

# %%
np.random.seed()
y = np.random.standard_normal(20)

# %%
x = range(len(y))
plt.plot(x,y)

# %%
plt.plot(y.cumsum()) #누적합

# %%
plt.plot(y.cumsum())
plt.grid(True)       # 경계 칸 그리기

# %%
plt.plot(y.cumsum())
plt.grid(True)       # 경계 칸 그리기
plt.axis('tight')    # tight : 모든자료 보이게 축 범위 조밀하게 조절
# Out:
# (-0.9500000000000001, 19.95, -0.9205385277168563, 4.576186872861326)

# %%
plt.plot(y.cumsum())
plt.grid(True)       # 경계 칸 그리기
plt.xlim(-1,25)
plt.ylim(np.min(y.cumsum())-2,np.max(y.cumsum())+3) # xlim, ylim : 축 범위 설정
# Out:
# (-2.6706873731451206, 7.326335718289591)

# %%
plt.figure(figsize = (7,5))         # 그림 크기
plt.plot(y.cumsum(),'b',lw = 1.5 )  # 선 색, 두께
plt.plot(y.cumsum(),'ro')           # 점, 점색
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')                 # x 축 이름
plt.ylabel('value')                 # y 축 이름
plt.title('A Simple plot')          # 그래프 이름
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %% [markdown]
# # 2차원 자료

# %%
np.random.seed(2000)
y = np.random.standard_normal((20,2)) # 20 X 2 난수 생성

# %%
y
# Out:
# array([[ 1.73673761,  1.89791391],
#        [-2.10677342, -0.14891209],
#        [ 0.58306155, -2.25923303],
#        [ 0.13723954, -0.70121322],
#        [-0.62078008, -0.47961976],
#        [ 1.20973877, -1.07518386],
#        [ 0.80691921, -0.29078347],
#        [-0.22094764, -0.16915604],
#        [ 1.10083444,  0.08251052],
#        [-0.00437558, -1.72255825],
#        [ 1.05755642, -2.51791281],
#        [-1.91064012,  1.30645535],
#        [ 0.42439764, -0.46916808],
#        [-1.00607253, -0.92192304],
#        [ 0.62640453,  0.3571767 ],
#        [-0.01871855,  0.22117127],
#        [ 0.69860411,  0.83451002],
#        [-1.66563784, -2.90143984],
#        [-0.04863853, -0.04537833],
#        [ 1.47533391, -0.51369344]])

# %%
y1 = y.cumsum(axis = 0)
y1
# Out:
# array([[ 1.73673761,  1.89791391],
#        [-0.37003581,  1.74900181],
#        [ 0.21302575, -0.51023122],
#        [ 0.35026529, -1.21144444],
#        [-0.27051479, -1.6910642 ],
#        [ 0.93922398, -2.76624806],
#        [ 1.74614319, -3.05703153],
#        [ 1.52519555, -3.22618757],
#        [ 2.62602999, -3.14367705],
#        [ 2.6216544 , -4.8662353 ],
#        [ 3.67921082, -7.38414811],
#        [ 1.7685707 , -6.07769276],
#        [ 2.19296834, -6.54686084],
#        [ 1.18689581, -7.46878388],
#        [ 1.81330034, -7.11160718],
#        [ 1.79458178, -6.89043591],
#        [ 2.49318589, -6.05592589],
#        [ 0.82754806, -8.95736573],
#        [ 0.77890953, -9.00274406],
#        [ 2.25424343, -9.51643749]])

# %%
plt.figure(figsize = (7,4))
plt.plot(y1,lw = 1.5)        
plt.plot(y1,'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple plot')
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %%
plt.figure(figsize = (7,4))
plt.plot(y1[:,0],lw = 1.5,label = '1st')
plt.plot(y1[:,1],lw = 1.5,label = '2st') # 여기서 label = 범례
plt.plot(y1,'ro')
plt.legend(loc = 0)                      # 범례 위치 조정( loc = 0 -> 알아서 최적위치로)
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple plot')
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %%
y1[:,1] = y1[:,1]* 100

plt.figure(figsize = (7,4))
plt.plot(y1[:,0],lw = 1.5,label = '1st')
plt.plot(y1[:,1],lw = 1.5,label = '2st')
plt.plot(y1,'ro')
plt.legend(loc = 0)                      
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple plot')             # 각 데이터가 괴리가 크면 시각적으로 표시 x
                                       # -> y축을 2개로 나눠서 표시
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %%
 # -> y 축 하나 더 사용

plt.figure(figsize = (7,4))
fig, ax1 = plt.subplots()
plt.plot(y1[:,0],'b',lw = 1.5,label = '1st')
plt.plot(y1[:,0],'ro')
plt.grid(True)
plt.legend(loc = 8)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A Simple plot')

# ------- 두번째 그래프 -------

ax2 = ax1.twinx()
plt.plot(y1[:,1],'g',lw = 1.5,label = '2nd')
plt.plot(y1[:,1],'ro')
plt.legend(loc = 0)
plt.ylabel('value 2nd')
# Out:
# Text(0, 0.5, 'value 2nd')

# %%
# 두 그래프를 분리

plt.figure(figsize = (7,4))
plt.subplot(211)                               # 2 x 1 에서 첫번째에 그린다.
plt.plot(y1[:,0],'b',lw = 1.5,label = '1st')
plt.plot(y1[:,0],'ro')
plt.grid(True)
plt.axis('tight')
plt.legend(loc = 0)
plt.ylabel('value 1st')
plt.title('A Simple plot')

# ------- 두번째 그래프 -------

plt.subplot(212)                               # 2 x 1 에서 두번째에 그린다.
plt.plot(y1[:,1],'g',lw = 1.5,label = '2st')
plt.plot(y1[:,1],'ro')
plt.grid(True)
plt.axis('tight')
plt.legend(loc = 0)
plt.ylabel('value 2nd')
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')

# %%
# 서로 다른 형식의 그래프를 그릴때 ( 선 and 바 그래프 동시에 )

plt.figure(figsize = (7,4))
plt.subplot(121)
plt.plot(y1[:,0],'b',lw = 1.5,label = '1st')
plt.plot(y1[:,0],'ro')
plt.grid(True)
plt.legend(loc = 0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('1st data set')

# ------- 두번째 그래프 -------

plt.subplot(122)
plt.bar(np.arange(len(y)),y[:,1],width = 0.5,color = 'g',label = '2nd')
plt.grid(True)
plt.legend(loc = 0)
plt.axis('tight')
plt.xlabel('index')
plt.title('2nd data set')
# Out:
# Text(0.5, 1.0, '2nd data set')

# %% [markdown]
# # 기타

# %%
# 스케터 플롯

# EX) 두개의 금융 시계열 자료의 수익률을 동시에 보일때 사용 가능

# %%
# 기존 그래프 방식

y = np.random.standard_normal((1000,2))
plt.figure(figsize=(7,5))
plt.plot(y[:,0],y[:,1],'ro')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# Scatter 방식

plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1], marker = 'o')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# Scatter는 세번째 차원 추가 가능 
# 그 값을 색을 통하여 시각화 가능( color bar를 이용)

c = np.random.randint(0,10,len(y))  # 0 부터 10 사이의 정수를 가지는 세번째 자료 생성

# %%
plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1],c=c, marker = 'o')
plt.colorbar()
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# 히스토그램

plt.figure(figsize = (7,4))
plt.hist(y, label = ['1st','2nd'], bins = 25)
plt.grid(True)
plt.legend(loc = 0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')

# 다른 인수들 - P.164
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# 여러 데이터를 쌓아 올리기
# 인수 - stacked 쌓아 올리는지 여부 

plt.figure(figsize = (7,4))
plt.hist(y, label = ['1st','2nd'],color = ['b','r'],stacked = True,rwidth = 0.7, bins = 35) # rwidth : 막대 폭
plt.grid(True)
plt.legend(loc = 0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# 박스플롯

fig, ax = plt.subplots(figsize = (7,4))
plt.boxplot(y)
plt.grid(True)
plt.setp(ax, xticklabels = ['1st','2nd']) # setp은 그래프의 선 스타일 변경가능 
                                          # EX) a = plt.plot(data,'r')
                                          # plt.setp(a, linestyle = '--')

plt.xlabel('data set')
plt.ylabel('value')
plt.title('Boxplot')
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
## 함수 적분 부분 그리기

from matplotlib.patches import Polygon

# 1. 함수 정의

def func(x):
    return 0.5 * np.exp(x) + 1

# 2. 함수구간 및 함수 값, 적분구간 정의

a, b = 0.5, 1.5
x = np.linspace(0,2)
y = func(x)

# 3. 함수 그리기

fig,ax = plt.subplots(figsize = (7,5))
plt.plot(x,y,'b',lw = 2)
plt.ylim(ymin = 0)

# 4.Polygon 함수 사용 -> 적분구간 그리기

ix = np.linspace(a,b)
iy = func(ix)
verts = [(a,0)]+list(zip(ix,iy))+[(b,0)]
poly = Polygon(verts, facecolor = '0.7', edgecolor = '0.5')
ax.add_patch(poly)

# 라벨 추가

plt.text(0.5 * (a+b), 1, r"$\int_a^b f(x)\mathrm{d}x$", horizontalalignment = 'center', fontsize = 20)
plt.figtext(0.9, 0.075, '$x$')
plt.figtext(0.075, 0.9, '$f(x)$')

# x,y 축의 틱값 표시
ax.set_xticks((a,b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([func(a), func(b)])
ax.set_yticklabels(('$f(a)$', '$f(b)$'))
plt.grid(True)

# %% [markdown]
# # 금융관련 플롯

# %%
import mpl_finance as mpf
from pandas_datareader import data as web
import matplotlib.ticker as ticker
import datetime

# %%
start = datetime.datetime(2014,5,1)
end = datetime.datetime(2014,6,30)

df = web.DataReader('^GDAXI', data_source = 'yahoo', start = start, end = end)
#df = df.reset_index()

#df['Date'] = df['Date'].apply(lambda x: x.toordinal())       #날짜를 숫자로 변환
quotes = [tuple(x) for x in df.to_records(index = False)]    # 인덱스 제외하고 튜플로 묶기

# %%
df
# Out:
#                     High          Low          Open         Close     Volume  \
# Date
# 2014-04-30   9618.980469  9561.059570   9576.929688   9603.230469   90290900
# 2014-05-02   9627.379883  9533.299805   9611.790039   9556.019531   88062300
# 2014-05-05   9548.169922  9407.089844   9536.379883   9529.500000   61911600
# 2014-05-06   9571.629883  9440.469727   9570.250000   9467.530273   82062900
# 2014-05-07   9554.349609  9410.080078   9418.500000   9521.299805   92732600
# 2014-05-08   9622.299805  9487.570312   9547.269531   9607.400391  102022500
# 2014-05-09   9602.860352  9558.110352   9591.320312   9581.450195   80084100
# 2014-05-12   9710.339844  9587.139648   9608.929688   9702.459961   87508500
# 2014-05-13   9783.719727  9732.339844   9751.049805   9754.429688   96844100
# 2014-05-14   9772.089844  9733.209961   9765.620117   9754.389648   76079000
# 2014-05-15   9810.290039  9631.570312   9741.250000   9656.049805  133897400
# ...

# %%
quotes
# Out:
# [(9618.98046875,
#   9561.0595703125,
#   9576.9296875,
#   9603.23046875,
#   90290900,
#   9603.23046875),
#  (9627.3798828125,
#   9533.2998046875,
#   9611.7900390625,
#   9556.01953125,
#   88062300,
#   9556.01953125),
#  (9548.169921875, 9407.08984375, 9536.3798828125, 9529.5, 61911600, 9529.5),
#  (9571.6298828125,
#   9440.4697265625,
#   9570.25,
#   9467.5302734375,
#   82062900,
#   9467.5302734375),
#  (9554.349609375,
#   9410.080078125,
#   9418.5,
#   9521.2998046875,
#   92732600,
#   9521.2998046875),
#  (9622.2998046875,
#   9487.5703125,
#   9547.26953125,
#   9607.400390625,
#   102022500,
#   9607.400390625),
#  (9602.8603515625,
#   9558.1103515625,
#   9591.3203125,
#   9581.4501953125,
#   80084100,
#   9581.4501953125),
#  (9710.33984375,
#   9587.1396484375,
#   9608.9296875,
#   9702.4599609375,
#   87508500,
#   9702.4599609375),
#  (9783.7197265625,
#   9732.33984375,
#   9751.0498046875,
#   9754.4296875,
#   96844100,
#   9754.4296875),
# ...

# %%
# 이 데이터를 캔들스틱 차트로 

fig, ax = plt.subplots(figsize= (10,5))
fig.subplots_adjust()
mpf.candlestick2_ohlc(ax, df['Open'],df['High'],df['Low'],df['Close'], width = 0.6, colorup = 'r',colordown = 'b')
plt.grid(True)

#ax.xaxis_date()
index = df.index.astype('str')
def x_date(x,pos):
    try:
        return index[int(x)]      #[8:] #-> 월까지만 표시
    except IndexError:
        return ''                 # x축에 날짜 표시

ax.xaxis.set_major_locator(ticker.MaxNLocator(5))    
ax.xaxis.set_major_formatter(ticker.FuncFormatter(x_date))
ax.autoscale_view()

# ---------------------check-----------------------

plt.gca().get_xticklabels() # gca - figure 객체 반환
                                                     # get_xticklabels() - x축의 틱라벨 객체 반환
                                                     # -> 30도 회전
# Out:
# <a list of 7 Text xticklabel objects>

# %%
# 다른 함수 - plot_day_summary_ohlc - 시가,종가가 사각형 X

fig, ax = plt.subplots(figsize = (11,8))
mpf.plot_day_summary2_ohlc(ax, df['Open'],df['High'],df['Low'],df['Close'], colorup = 'b', colordown = 'r')
plt.grid(True)

#ax.xaxis_date()
index = df.index.astype('str')
def x_date(x,pos):
    try:
        return index[int(x)] #[8:]    # -> 월까지만 표시
    except IndexError:
        return ''                     # x축에 날짜 표시

ax.xaxis.set_major_locator(ticker.MaxNLocator(5))           # 축?? 개수 조정
ax.xaxis.set_major_formatter(ticker.FuncFormatter(x_date))  # 날짜 삽입

plt.title('DAX index')
plt.ylabel('index level')

#------------------check-------------------

#plt.setp(plt.gca().get_xticklabels(), rotation = 30)
# Out:
# Text(0, 0.5, 'index level')

# %%
df = web.DataReader('^GDAXI', data_source = 'yahoo', start = start, end = end)
#df = df.reset_index()
#df['Date'] = df['Date'].apply(lambda x: x.toordinal())
quotes = [tuple(x) for x in df.to_records(index = False)]
quotes = np.array(quotes)

# %%
df
# Out:
#                     High          Low          Open         Close     Volume  \
# Date
# 2014-04-30   9618.980469  9561.059570   9576.929688   9603.230469   90290900
# 2014-05-02   9627.379883  9533.299805   9611.790039   9556.019531   88062300
# 2014-05-05   9548.169922  9407.089844   9536.379883   9529.500000   61911600
# 2014-05-06   9571.629883  9440.469727   9570.250000   9467.530273   82062900
# 2014-05-07   9554.349609  9410.080078   9418.500000   9521.299805   92732600
# 2014-05-08   9622.299805  9487.570312   9547.269531   9607.400391  102022500
# 2014-05-09   9602.860352  9558.110352   9591.320312   9581.450195   80084100
# 2014-05-12   9710.339844  9587.139648   9608.929688   9702.459961   87508500
# 2014-05-13   9783.719727  9732.339844   9751.049805   9754.429688   96844100
# 2014-05-14   9772.089844  9733.209961   9765.620117   9754.389648   76079000
# 2014-05-15   9810.290039  9631.570312   9741.250000   9656.049805  133897400
# ...

# %%
index
# Out:
# Index(['2014-04-30', '2014-05-02', '2014-05-05', '2014-05-06', '2014-05-07',
#        '2014-05-08', '2014-05-09', '2014-05-12', '2014-05-13', '2014-05-14',
#        '2014-05-15', '2014-05-16', '2014-05-19', '2014-05-20', '2014-05-21',
#        '2014-05-22', '2014-05-23', '2014-05-26', '2014-05-27', '2014-05-28',
#        '2014-05-29', '2014-05-30', '2014-06-02', '2014-06-03', '2014-06-04',
#        '2014-06-05', '2014-06-06', '2014-06-09', '2014-06-10', '2014-06-11',
#        '2014-06-12', '2014-06-13', '2014-06-16', '2014-06-17', '2014-06-18',
#        '2014-06-19', '2014-06-20', '2014-06-23', '2014-06-24', '2014-06-25',
#        '2014-06-26', '2014-06-27', '2014-06-30'],
#       dtype='object', name='Date')

# %%
fig,(ax1,ax2) = plt.subplots(2, sharex = True, figsize = (10,10))
fig.subplots_adjust()
mpf.candlestick2_ohlc(ax1, df['Open'],df['High'],df['Low'],df['Close'], width = 0.6, colorup = 'r',colordown = 'b')
ax1.set_title('DAX Inc.')
ax1.set_ylabel('index level')
ax1.grid(True)


plt.bar(index,quotes[:,4],width = 0.5)
ax2.set_ylabel('volume')
ax2.grid(True)
ax2.autoscale_view()

# %%
strike = np.linspace(50,150,24)
ttm = np.linspace(0.5,2.5,24)

# %%
strike
# Out:
# array([ 50.        ,  54.34782609,  58.69565217,  63.04347826,
#         67.39130435,  71.73913043,  76.08695652,  80.43478261,
#         84.7826087 ,  89.13043478,  93.47826087,  97.82608696,
#        102.17391304, 106.52173913, 110.86956522, 115.2173913 ,
#        119.56521739, 123.91304348, 128.26086957, 132.60869565,
#        136.95652174, 141.30434783, 145.65217391, 150.        ])

# %%
strike, ttm = np.meshgrid(strike,ttm)

# %%
strike
# Out:
# array([[ 50.        ,  54.34782609,  58.69565217,  63.04347826,
#          67.39130435,  71.73913043,  76.08695652,  80.43478261,
#          84.7826087 ,  89.13043478,  93.47826087,  97.82608696,
#         102.17391304, 106.52173913, 110.86956522, 115.2173913 ,
#         119.56521739, 123.91304348, 128.26086957, 132.60869565,
#         136.95652174, 141.30434783, 145.65217391, 150.        ],
#        [ 50.        ,  54.34782609,  58.69565217,  63.04347826,
#          67.39130435,  71.73913043,  76.08695652,  80.43478261,
#          84.7826087 ,  89.13043478,  93.47826087,  97.82608696,
#         102.17391304, 106.52173913, 110.86956522, 115.2173913 ,
#         119.56521739, 123.91304348, 128.26086957, 132.60869565,
#         136.95652174, 141.30434783, 145.65217391, 150.        ],
#        [ 50.        ,  54.34782609,  58.69565217,  63.04347826,
#          67.39130435,  71.73913043,  76.08695652,  80.43478261,
#          84.7826087 ,  89.13043478,  93.47826087,  97.82608696,
# ...

# %%
iv = (strike-100)**2/(100*strike)/ttm

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (9,6))
ax = fig.gca(projection = '3d')

surf = ax.plot_surface(strike, ttm, iv, rstride = 2, cstride = 2, cmap = plt.cm.coolwarm, linewidth = 0.5, antialiased = True)
ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')

fig.colorbar(surf, shrink = 0.5, aspect = 5)

# %%
fig = plt.figure(figsize = (8,5))
ax = fig.add_subplot(111,projection = '3d')
ax.view_init(30,60)        # 그래프 회전

ax.scatter(strike, ttm, iv, zdir = 'z', s = 25, c = 'b', marker = '^')
                          # z축 기준으로 # 마커사이즈 25
    
ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')
# Out:
# Text(0.5, 0, 'implied volatility')
